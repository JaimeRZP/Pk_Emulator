# %% [markdown]
# # Feynman  Method

# %% [markdown]
# I have found some examples on how to run the code but it only seems to work with scalar equations?
# https://github.com/dcshapiro/AI-Feynman/blob/master/AI_Feynman_2_0.ipynb
#
# I wonder if the code even works for vector equations.

# %%
import aifeynman

# %%
aifeynman.get_demos("example_data") # Download examples from server
aifeynman.run_aifeynman("/home/zcapjru/PhD/AI-Feynman/example_data/", "example1.txt", 60, "14ops.txt", polyfit_deg=3, NN_epochs=500)
# Out:
# downloading...
# example1.txt
# https://space.mit.edu/home/tegmark/aifeynman/example_data/example1.txt
# example_data/example1.txt
# example2.txt
# https://space.mit.edu/home/tegmark/aifeynman/example_data/example2.txt
# example_data/example2.txt
# example3.txt
# https://space.mit.edu/home/tegmark/aifeynman/example_data/example3.txt
# example_data/example3.txt
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve /home/zcapjru/PhD/AI-Feynman/example_data/example1.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve /home/zcapjru/PhD/AI-Feynman/example_data/example1.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 0.0 30.84 0
# ...
